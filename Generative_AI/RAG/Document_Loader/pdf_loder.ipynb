# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("hello.pdf")

docs = loader.load()
print(docs)
print(len(docs))
print(docs[0].page_content)
print(docs[1].metadata)
# Out:
# [Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Historical Stick Figure Animation Masterclass', 'source': 'hello.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Historical  Stick  Figure  Animation  Masterclass   Analyse  Analyse  the  title  patterns,  hook  structures,  and  script  formats  across  these  videos.  Give  \nme\n \na\n \n1-paragraph\n \nsummary\n \nof\n \nwhat\n \nmakes\n \nthese\n \nvideos\n \nwork\n \n—\n \nformat,\n \nepisode\n \nlength,\n \nPOV\n \nstyle,\n \npacing,\n \nand\n \nstory\n \narc.\n \n   \nTopic\n Using  the  same  title  format  and  script  structure  as  these  videos,  write  5  viral  title  options  \nfor\n \na\n \nnew\n \ninteresting\n \nepisode.\n \nKeep\n \nthem\n \ndirect,\n \nsearch-friendly,\n \nand\n \nmatched\n \nto\n \nthe\n \nchannel\'s\n \npattern.\n \nI\'ll\n \nchoose\n \nthe\n \nwinner,\n \nthen\n \nyou\n \nwrite\n \nthe\n \nentire\n \nscri
# ...

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\sanga\Desktop\AI_ML_and_Generative_AI\Generative_AI\.venv\Scripts\python.exe

# %%
import pypdf

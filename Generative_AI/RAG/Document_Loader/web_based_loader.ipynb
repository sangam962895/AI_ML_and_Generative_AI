# %%
from langchain_community.document_loaders import WebBaseLoader

url = "https://www.flipkart.com/search?q=macbook&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
loader = WebBaseLoader(url)

docs = loader.load()

print(len(docs))
print(docs[0].page_content)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 6
#       2
#       3 url = "https://www.flipkart.com/search?q=macbook&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
#       4 loader = WebBaseLoader(url)
#       5
# ----> 6 docs = loader.load()
#       7
#       8 print(len(docs))
#       9 print(docs[0].page_content)
#
# File c:\Users\sanga\Desktop\AI_ML_and_Generative_AI\Generative_AI\.venv\Lib\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# File c:\Users\sanga\Desktop\AI_ML_and_Generative_AI\Generative_AI\.venv\Lib\site-packages\langchain_community\document_loaders\web_base.py:375, in WebBaseLoader.lazy_load(self)
#     373 """Lazy load text from the url(s) in web_path."""
#     374 for path in self.web_paths:
# --> 375     soup = self._scrape(path, bs_kwargs=self.bs_kwargs)
#     376     text = soup.get_text(**self.bs_get_text_kwargs)
#     377     metadata = _build_metadata(soup, path)
#
# File c:\Users\sanga\Desktop\AI_ML_and_Generative_AI\Generative_AI\.venv\Lib\site-packages\langchain_community\document_loaders\web_base.py:347, in WebBaseLoader._scrape(self, url, parser, bs_kwargs)
#     341 def _scrape(
#     342     self,
#     343     url: str,
#     344     parser: Union[str, None] = None,
#     345     bs_kwargs: Optional[dict] = None,
#     346 ) -> Any:
# --> 347     from bs4 import BeautifulSoup
#     349     if parser is None:
#     350         if url.endswith(".xml"):
#
# ModuleNotFoundError: No module named 'bs4'

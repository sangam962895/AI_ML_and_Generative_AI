# %%
import os
from langchain_community.document_loaders import TextLoader
from langchain_groq import ChatGroq
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from dotenv import load_dotenv

load_dotenv()

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key=os.getenv("GROQ_API_KEY")
)

prompt = PromptTemplate(
    template = "write a summary for the following poem - \n {poem}",
    input_variables=['poem']
)

parser = StrOutputParser()


loader = TextLoader("Cricket_Info.txt", encoding="utf-8")

docs = loader.load()

# print(type(docs))          # <class 'list'>
# print(len(docs))           # 1
# print(type(docs[0]))       # langchain_core.documents.base.Document

print(docs[0].page_content)   # Prints the text inside the file
print(docs[0].metadata)

chain = prompt | llm | parser

print(chain.invoke({'poem':docs[0].page_content}))

# import os

# from langchain_community.document_loaders import TextLoader
# from langchain_groq import ChatGroq
# from langchain_core.output_parsers import StrOutputParser
# from langchain_core.prompts import PromptTemplate
# from dotenv import load_dotenv

# load_dotenv()

# llm = ChatGroq(
#     model="llama-3.3-70b-versatile",
#     api_key=os.getenv("GROQ_API_KEY")
# )

# prompt = PromptTemplate(
#     template="Write a summary for the following text:\n\n{text}",
#     input_variables=["text"]
# )

# parser = StrOutputParser()

# loader = TextLoader("Cricket_Info.txt", encoding="utf-8")
# docs = loader.load()

# chain = prompt | llm | parser

# response = chain.invoke({"text": docs[0].page_content})

# print(response)
# Out:
# METADATA
#
# Title: Cricket Information Author: ChatGPT Category: Sports Language:
# English Encoding: UTF-8 Version: 1.0 Source: Custom Sample Created:
# 2026-07-22
#
# CONTENT
#
# Cricket is one of the world’s most popular sports, played between two
# teams of eleven players.
#
# Basic Rules - One team bats while the other bowls and fields. - The
# batting team scores runs. - The bowling team tries to dismiss batters. -
# The team with the most runs wins.
#
# Formats - Test Cricket - One Day Internationals (ODIs) - Twenty20 (T20)
#
# Famous Skills - Batting - Bowling - Fielding - Wicketkeeping
#
# Cricket combines strategy, teamwork, and skill, making it an exciting
# sport for players and fans alike.
#
# {'source': 'Cricket_Info.txt'}
# The poem provides an overview of the sport of cricket, covering its basic rules, formats, and key skills. It explains that two teams of eleven players compete, with one team batting and the other bowling and fielding, and the team with the most runs declared the winner. The poem also highlights the different formats of the game, including Test Cricket, One Day Internationals, and Twenty20, as well as the important skills required, such as batting, bowling, fielding, and wicketkeeping. Overall, the poem portrays cricket as a thrilling and strategic sport that requires teamwork and skill.

# %%
print()
